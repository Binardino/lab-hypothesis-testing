# %% [markdown]
# # Before your start:
# - Read the README.md file
# - Comment as much as you can and use the resources (README.md file)
# - Happy learning!

# %%
# import numpy and pandas
import numpy as np
import pandas as pd
import pandas as pd
import pymysql
from sqlalchemy import create_engine

# %% [markdown]
# # Challenge 1 - Exploring the Data
#
# In this challenge, we will examine all salaries of employees of the City of Chicago. We will start by loading the dataset and examining its contents. Please, load the data using Ironhack's database (db: employees, table: employees_advanced).

# %%
# Your code here:
driver   = 'mysql+pymysql:'
user     = 'data-students'
password = 'iR0nH@cK-D4T4B4S3'
ip       = '34.65.10.136'
database = 'employees'

connection_string = f'{driver}//{user}:{password}@{ip}/{database}'
print(connection_string)

engine = create_engine(connection_string)
print(engine)

pd.read_sql('SHOW TABLES;', engine)
# Out:
# mysql+pymysql://data-students:iR0nH@cK-D4T4B4S3@34.65.10.136/employees
# Engine(mysql+pymysql://data-students:***@34.65.10.136/employees)
#   Tables_in_employees
# 0            absences
# 1           employees
# 2  employees_advanced

# %%
df_employees_advanced = pd.read_sql('SELECT * FROM employees_advanced', engine)

df_employees_advanced
# Out:
#                         Name                              Job Titles  \
# 0          AARON,  JEFFERY M                                SERGEANT
# 1            AARON,  KARINA   POLICE OFFICER (ASSIGNED AS DETECTIVE)
# 2        AARON,  KIMBERLEI R                CHIEF CONTRACT EXPEDITER
# 3        ABAD JR,  VICENTE M                       CIVIL ENGINEER IV
# 4          ABASCAL,  REECE E             TRAFFIC CONTROL AIDE-HOURLY
# ...                      ...                                     ...
# 33178  ZYLINSKA,  KATARZYNA                           POLICE OFFICER
# 33179     ZYMANTAS,  LAURA C                          POLICE OFFICER
# 33180      ZYMANTAS,  MARK E                          POLICE OFFICER
# 33181    ZYRKOWSKI,  CARLO E                          POLICE OFFICER
# 33182   ZYSKOWSKI,  DARIUSZ                  CHIEF DATA BASE ANALYST
#
#              Department Full or Part-Time Salary or Hourly  Typical Hours  \
# ...

# %%
df_employees_advanced.to_csv('employees.csv')

# %%
df_employees_advanced = pd.read_csv('employees.csv')

# %% [markdown]
# Examine the `salaries` dataset using the `head` function below.

# %%
# Your code here:
df_employees_advanced.head
# Out:
# <bound method NDFrame.head of                         Name                              Job Titles  \
# 0          AARON,  JEFFERY M                                SERGEANT
# 1            AARON,  KARINA   POLICE OFFICER (ASSIGNED AS DETECTIVE)
# 2        AARON,  KIMBERLEI R                CHIEF CONTRACT EXPEDITER
# 3        ABAD JR,  VICENTE M                       CIVIL ENGINEER IV
# 4          ABASCAL,  REECE E             TRAFFIC CONTROL AIDE-HOURLY
# ...                      ...                                     ...
# 33178  ZYLINSKA,  KATARZYNA                           POLICE OFFICER
# 33179     ZYMANTAS,  LAURA C                          POLICE OFFICER
# 33180      ZYMANTAS,  MARK E                          POLICE OFFICER
# 33181    ZYRKOWSKI,  CARLO E                          POLICE OFFICER
# 33182   ZYSKOWSKI,  DARIUSZ                  CHIEF DATA BASE ANALYST
#
#              Department Full or Part-Time Salary or Hourly  Typical Hours  \
# ...

# %% [markdown]
# We see from looking at the `head` function that there is quite a bit of missing data. Let's examine how much missing data is in each column. Produce this output in the cell below

# %%
# Counting null values through isna().sum()
df_employees_advanced.isna().sum()
# Out:
# Name                     0
# Job Titles               0
# Department               0
# Full or Part-Time        0
# Salary or Hourly         0
# Typical Hours        25161
# Annual Salary         8022
# Hourly Rate          25161
# dtype: int64

# %%
df_employees_advanced_null = df_employees_advanced[df_employees_advanced['Annual Salary'].isnull()]

# %%
df_employees_advanced_null
# Out:
#                          Name                      Job Titles  \
# 4           ABASCAL,  REECE E     TRAFFIC CONTROL AIDE-HOURLY
# 6       ABBATACOLA,  ROBERT J             ELECTRICAL MECHANIC
# 7          ABBATE,  JOSEPH L          POOL MOTOR TRUCK DRIVER
# 10           ABBOTT,  BETTY L              FOSTER GRANDPARENT
# 18       ABDULLAH,  LAKENYA N                  CROSSING GUARD
# ...                       ...                             ...
# 33164        ZUREK,  FRANCIS              ELECTRICAL MECHANIC
# 33168  ZWARYCZ MANN,  IRENE A                  CROSSING GUARD
# 33169      ZWARYCZ,  THOMAS J         POOL MOTOR TRUCK DRIVER
# 33174        ZYGADLO,  JOHN P          MACHINIST (AUTOMOTIVE)
# 33175     ZYGADLO,  MICHAEL J  FRM OF MACHINISTS - AUTOMOTIVE
#
#              Department Full or Part-Time Salary or Hourly  Typical Hours  \
# 4                  OEMC                 P           Hourly           20.0
# ...

# %% [markdown]
# Let's also look at the count of hourly vs. salaried employees. Write the code in the cell below

# %%
# Your code here:

df_employees_advanced.groupby('Salary or Hourly').agg('count')
# Out:
#                   Unnamed: 0   Name  Job Titles  Department  \
# Salary or Hourly
# Hourly                  8022   8022        8022        8022
# Salary                 25161  25161       25161       25161
#
#                   Full or Part-Time  Typical Hours  Annual Salary  Hourly Rate
# Salary or Hourly
# Hourly                         8022           8022              0         8022
# Salary                        25161              0          25161            0

# %% [markdown]
# What this information indicates is that the table contains information about two types of employees - salaried and hourly. Some columns apply only to one type of employee while other columns only apply to another kind. This is why there are so many missing values. Therefore, we will not do anything to handle the missing values.

# %% [markdown]
# There are different departments in the city. List all departments and the count of employees in each department.

# %%
# Your code here:
df_employees_advanced.groupby('Department', sort=False).agg({'Job Titles':'count'})
# Out:
#                        Job Titles
# Department
# POLICE                      13414
# GENERAL SERVICES              980
# WATER MGMNT                  1879
# OEMC                         2102
# CITY COUNCIL                  411
# AVIATION                     1629
# STREETS & SAN                2198
# FIRE                         4641
# FAMILY & SUPPORT              615
# PUBLIC LIBRARY               1015
# TRANSPORTN                   1140
# MAYOR'S OFFICE                 85
# HEALTH                        488
# BUSINESS AFFAIRS              171
# LAW                           407
# FINANCE                       560
# CULTURAL AFFAIRS               65
# COMMUNITY DEVELOPMENT         207
# PROCUREMENT                    92
# BUILDINGS                     269
# ANIMAL CONTRL                  81
# CITY CLERK                     84
# BOARD OF ELECTION             107
# DISABILITIES                   28
# HUMAN RESOURCES                79
# DoIT                           99
# ...

# %% [markdown]
# # Challenge 2 - Hypothesis Tests
#
# In this section of the lab, we will test whether the hourly wage of all hourly workers is significantly different from $30/hr. Import the correct one sample test function from scipy and perform the hypothesis test for a 95% two sided confidence interval.

# %%
# Your code here:
# hourly wage different from $30/h ?!
from scipy.stats import ttest_1samp

# %%
hour_30 = df_employees_advanced[df_employees_advanced['Salary or Hourly'] == 'Hourly']

# %%
hour_30
# Out:
#        Unnamed: 0                    Name                      Job Titles  \
# 4               4       ABASCAL,  REECE E     TRAFFIC CONTROL AIDE-HOURLY
# 6               6   ABBATACOLA,  ROBERT J             ELECTRICAL MECHANIC
# 7               7      ABBATE,  JOSEPH L          POOL MOTOR TRUCK DRIVER
# 10             10        ABBOTT,  BETTY L              FOSTER GRANDPARENT
# 18             18    ABDULLAH,  LAKENYA N                  CROSSING GUARD
# ...           ...                     ...                             ...
# 33164       33164        ZUREK,  FRANCIS              ELECTRICAL MECHANIC
# 33168       33168  ZWARYCZ MANN,  IRENE A                  CROSSING GUARD
# 33169       33169      ZWARYCZ,  THOMAS J         POOL MOTOR TRUCK DRIVER
# 33174       33174        ZYGADLO,  JOHN P          MACHINIST (AUTOMOTIVE)
# 33175       33175     ZYGADLO,  MICHAEL J  FRM OF MACHINISTS - AUTOMOTIVE
#
#              Department Full or Part-Time Salary or Hourly  Typical Hours  \
# ...

# %%
h0 = 30

ttest_1samp(hour_30['Hourly Rate'], h0)
# Out:
# Ttest_1sampResult(statistic=20.6198057854942, pvalue=4.3230240486229894e-92)

# %%
#pvalue extremly low = null hypothesis highly unlikely, so we can confidently reject the hypothesis

# %% [markdown]
# We are also curious about salaries in the police force. The chief of police in Chicago claimed in a press briefing that salaries this year are higher than last year's mean of $86000/year a year for all salaried employees. Test this one sided hypothesis using a 95% confidence interval.
#
# Hint: A one tailed test has a p-value that is half of the two tailed p-value. If our hypothesis is greater than, then to reject, the test statistic must also be positive.

# %%
# Your code here:
h0_86k = 86000

police_annual_rate = df_employees_advanced[(df_employees_advanced['Annual Salary'].notnull()) & (df_employees_advanced['Department'] == 'POLICE')]

# %%
police_annual_rate
# Out:
#        Unnamed: 0                    Name  \
# 0               0       AARON,  JEFFERY M
# 1               1         AARON,  KARINA
# 9               9        ABBATE,  TERRY M
# 11             11        ABDALLAH,  ZAID
# 12             12  ABDELHADI,  ABDALMAHD
# ...           ...                     ...
# 33177       33177        ZYGMUNT,  DAWID
# 33178       33178   ZYLINSKA,  KATARZYNA
# 33179       33179      ZYMANTAS,  LAURA C
# 33180       33180       ZYMANTAS,  MARK E
# 33181       33181     ZYRKOWSKI,  CARLO E
#
#                                    Job Titles Department Full or Part-Time  \
# 0                                    SERGEANT     POLICE                 F
# 1      POLICE OFFICER (ASSIGNED AS DETECTIVE)     POLICE                 F
# 9                              POLICE OFFICER     POLICE                 F
# 11                             POLICE OFFICER     POLICE                 F
# 12                             POLICE OFFICER     POLICE                 F
# ...

# %%
ttest_1samp(police_annual_rate['Annual Salary'], h0_86k)
# Out:
# Ttest_1sampResult(statistic=3.081997005712994, pvalue=0.0020603403550965137)

# %%
# the p value is not that low, but with 2%, we are still in the confidence interval below the 5%, so we can reject the hypothesis 
#& confirm the chief of the Police department

# %% [markdown]
# Using the `crosstab` function, find the department that has the most hourly workers.

# %%
annual_rate = df_employees_advanced[df_employees_advanced['Salary or Hourly'] == 'Hourly']

# %%
annual_rate
# Out:
#        Unnamed: 0                    Name                      Job Titles  \
# 4               4       ABASCAL,  REECE E     TRAFFIC CONTROL AIDE-HOURLY
# 6               6   ABBATACOLA,  ROBERT J             ELECTRICAL MECHANIC
# 7               7      ABBATE,  JOSEPH L          POOL MOTOR TRUCK DRIVER
# 10             10        ABBOTT,  BETTY L              FOSTER GRANDPARENT
# 18             18    ABDULLAH,  LAKENYA N                  CROSSING GUARD
# ...           ...                     ...                             ...
# 33164       33164        ZUREK,  FRANCIS              ELECTRICAL MECHANIC
# 33168       33168  ZWARYCZ MANN,  IRENE A                  CROSSING GUARD
# 33169       33169      ZWARYCZ,  THOMAS J         POOL MOTOR TRUCK DRIVER
# 33174       33174        ZYGADLO,  JOHN P          MACHINIST (AUTOMOTIVE)
# 33175       33175     ZYGADLO,  MICHAEL J  FRM OF MACHINISTS - AUTOMOTIVE
#
#              Department Full or Part-Time Salary or Hourly  Typical Hours  \
# ...

# %%
# Your code here:
crosstable = pd.crosstab(annual_rate['Department'], annual_rate['Salary or Hourly'])
# crosstable.sort_values()

# %%
crosstable
# Out:
# Salary or Hourly       Hourly
# Department
# ANIMAL CONTRL              19
# AVIATION                 1082
# BUDGET & MGMT               2
# BUSINESS AFFAIRS            7
# CITY COUNCIL               64
# COMMUNITY DEVELOPMENT       4
# CULTURAL AFFAIRS            7
# FAMILY & SUPPORT          287
# FINANCE                    44
# FIRE                        2
# GENERAL SERVICES          765
# HEALTH                      3
# HUMAN RESOURCES             4
# LAW                        40
# MAYOR'S OFFICE              8
# OEMC                     1273
# POLICE                     10
# PROCUREMENT                 2
# PUBLIC LIBRARY            299
# STREETS & SAN            1862
# TRANSPORTN                725
# WATER MGMNT              1513

# %%
crosstable.sort_values(by='Hourly', ascending=False)

#The department STREETS & SAN is the one having the most working hours
# Out:
# Salary or Hourly       Hourly
# Department
# STREETS & SAN            1862
# WATER MGMNT              1513
# OEMC                     1273
# AVIATION                 1082
# GENERAL SERVICES          765
# TRANSPORTN                725
# PUBLIC LIBRARY            299
# FAMILY & SUPPORT          287
# CITY COUNCIL               64
# FINANCE                    44
# LAW                        40
# ANIMAL CONTRL              19
# POLICE                     10
# MAYOR'S OFFICE              8
# CULTURAL AFFAIRS            7
# BUSINESS AFFAIRS            7
# HUMAN RESOURCES             4
# COMMUNITY DEVELOPMENT       4
# HEALTH                      3
# FIRE                        2
# PROCUREMENT                 2
# BUDGET & MGMT               2

# %%
crosstable.columns
# Out:
# Index(['Hourly'], dtype='object', name='Salary or Hourly')

# %%
street_san = df_employees_advanced[df_employees_advanced['Department'] == 'STREETS & SAN']

# %%
street_san
# Out:
#        Unnamed: 0                    Name               Job Titles  \
# 7               7      ABBATE,  JOSEPH L   POOL MOTOR TRUCK DRIVER
# 21             21   ABDUL-SHAKUR,  TAHIR     GENERAL LABORER - DSS
# 24             24  ABERCROMBIE,  TIMOTHY        MOTOR TRUCK DRIVER
# 36             36     ABRAMS,  DANIELLE T       SANITATION LABORER
# 39             39       ABRAMS,  SAMUEL A  POOL MOTOR TRUCK DRIVER
# ...           ...                     ...                      ...
# 33107       33107         ZIZUMBO,  LUIS        MOTOR TRUCK DRIVER
# 33147       33147        ZUMMO,  ROBERT J       MOTOR TRUCK DRIVER
# 33149       33149     ZUNICH,  JONATHAN G       SANITATION LABORER
# 33156       33156        ZUNIGA,  THOMAS     GENERAL LABORER - DSS
# 33162       33162       ZURAWSKI,  MAC Z   REFUSE COLLECTION COORD
#
#           Department Full or Part-Time Salary or Hourly  Typical Hours  \
# 7      STREETS & SAN                 F           Hourly           40.0
# ...

# %% [markdown]
# The workers from the department with the most hourly workers have complained that their hourly wage is less than $35/hour. Using a one sample t-test, test this one-sided hypothesis at the 95% confidence level.

# %%
# Your code here:
h_35 = 35
ttest_1samp(street_san['Hourly Rate'], h_35)
# Out:
# c:\users\langl\appdata\local\programs\python\python38\lib\site-packages\scipy\stats\_distn_infrastructure.py:903: RuntimeWarning: invalid value encountered in greater
#   return (a < x) & (x < b)
# c:\users\langl\appdata\local\programs\python\python38\lib\site-packages\scipy\stats\_distn_infrastructure.py:903: RuntimeWarning: invalid value encountered in less
#   return (a < x) & (x < b)
# c:\users\langl\appdata\local\programs\python\python38\lib\site-packages\scipy\stats\_distn_infrastructure.py:1912: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= _a)
# Ttest_1sampResult(statistic=nan, pvalue=nan)

# %% [markdown]
# # Challenge 3: To practice - Constructing Confidence Intervals
#
# While testing our hypothesis is a great way to gather empirical evidence for accepting or rejecting the hypothesis, another way to gather evidence is by creating a confidence interval. A confidence interval gives us information about the true mean of the population. So for a 95% confidence interval, we are 95% sure that the mean of the population is within the confidence interval.
# ).
#
# To read more about confidence intervals, click [here](https://en.wikipedia.org/wiki/Confidence_interval).
#
#
# In the cell below, we will construct a 95% confidence interval for the mean hourly wage of all hourly workers.
#
# The confidence interval is computed in SciPy using the `t.interval` function. You can read more about this function [here](https://docs.scipy.org/doc/scipy-0.14.0/reference/generated/scipy.stats.t.html).
#
# To compute the confidence interval of the hourly wage, use the 0.95 for the confidence level, number of rows - 1 for degrees of freedom, the mean of the sample for the location parameter and the standard error for the scale. The standard error can be computed using [this](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.sem.html) function in SciPy.

# %%
from scipy import stats

# %%
hourly = df_employees_advanced[df_employees_advanced['Hourly Rate'].notnull()]

# %%
# Your code here:

# scipy.stats.sem(a, axis=0, ddof=1, nan_policy='propagate')
s_error = stats.sem(hourly, axis=0, ddof=1)

mean_hour_wage = np.mean(df_employees_advanced['Hourly Rate'])

interval_norm = stats.norm.interval(0.95, loc=mean_hour_wage, scale=s_error)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-71-4a1866f12251> in <module>
#       2
#       3 # scipy.stats.sem(a, axis=0, ddof=1, nan_policy='propagate')
# ----> 4 s_error = stats.sem(hourly, axis=0, ddof=1)
#       5
#       6 mean_hour_wage = np.mean(df_employees_advanced['Hourly Rate'])
#
# c:\users\langl\appdata\local\programs\python\python38\lib\site-packages\scipy\stats\stats.py in sem(a, axis, ddof, nan_policy)
#    2343
#    2344     n = a.shape[axis]
# -> 2345     s = np.std(a, axis=axis, ddof=ddof) / np.sqrt(n)
#    2346     return s
#    2347
#
# <__array_function__ internals> in std(*args, **kwargs)
#
# c:\users\langl\appdata\local\programs\python\python38\lib\site-packages\numpy\core\fromnumeric.py in std(a, axis, dtype, out, ddof, keepdims)
#    3456             return std(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)
#    3457
# ...

# %% [markdown]
# Now construct the 95% confidence interval for all salaried employeed in the police in the cell below.

# %%
# Your code here:

# %% [markdown]
# # Bonus Challenge - Hypothesis Tests of Proportions
#
# Another type of one sample test is a hypothesis test of proportions. In this test, we examine whether the proportion of a group in our sample is significantly different than a fraction.
#
# You can read more about one sample proportion tests [here](http://sphweb.bumc.bu.edu/otlt/MPH-Modules/BS/SAS/SAS6-CategoricalData/SAS6-CategoricalData2.html).
#
# In the cell below, use the `proportions_ztest` function from `statsmodels` to perform a hypothesis test that will determine whether the number of hourly workers in the City of Chicago is significantly different from 25% at the 95% confidence level.

# %%
# Your code here:
